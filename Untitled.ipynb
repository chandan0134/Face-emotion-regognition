# %%
import cv2

# %%
from deepface import DeepFace

# %%
img =cv2.imread("istockphoto-1132930732-170667a.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
prediction=DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 62ms/step
# Action: age:  25%|█████████████▊                                         | 1/4 [00:00<00:00,  4.43it/s]
# 1/1 [==============================] - 1s 537ms/step
# Action: gender:  50%|██████████████████████████                          | 2/4 [00:00<00:01,  1.92it/s]
# 1/1 [==============================] - 1s 503ms/step
# Action: race:  75%|████████████████████████████████████████▌             | 3/4 [00:01<00:00,  1.80it/s]
# 1/1 [==============================] - 1s 532ms/step
# Action: race: 100%|██████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.84it/s]

# %%
type(prediction)
# Out:
# dict

# %%
prediction('dominant_race')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14576/459610535.py in <module>
# ----> 1 prediction('dominant_race')
#
# TypeError: 'dict' object is not callable
